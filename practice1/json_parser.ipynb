# %%
import requests
import pandas as pd

# %%
cookies = {
    'is_seo_or_robot': 'seo',
    'srv_menu_gender': 'women',
    'lid': 'ZEACoWVY/fETVxk3poJPAgA=',
    '_gcl_au': '1.1.2004159184.1700330994',
    'uxs_uid': 'acd8f210-863d-11ee-ac5a-295603813e4e',
    'lmda_adBlocker': '0',
    'lmda_site_version': '23.11.16',
    'wt3_sid': '%3B717012440280310',
    'sessionId': '17003309958823931367',
    'is_synced': 'true',
    '_gid': 'GA1.2.1095965336.1700330997',
    'tmr_lvid': '46e9ae520e08993a09fbd7096e3fefba',
    'tmr_lvidTS': '1700330996939',
    '_sp_ses.d14a': '*',
    '_ym_uid': '1700330997312631445',
    '_ym_d': '1700330997',
    '_ym_isad': '1',
    '_ym_visorc': 'b',
    'wt_geid': '68934a3e9455fa72420237eb',
    'search_gender': '',
    'qrator_ssid': '1700330996.915.z7tIogZNFVoG0Rzj-uudfhjvdpq77k1v1thvdtmvmhd64iku9',
    'gd_city': '%D0%B3.%20%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0',
    'gd_aoid': '7700000000000',
    'LMDA': 'gd_lat=55.755814:gd_long=37.617635',
    'wt_cdbeid': '1',
    'wt3_eid': '%3B717012440280310%7C2170033099598295355%232170033193455695664',
    'wt_rla': '717012440280310%2C13%2C1700330995867',
    '_ga': 'GA1.2.543282526.1700330997',
    '_dc_gtm_UA-20431685-1': '1',
    '_sp_id.d14a': 'c625dc77-ec72-45fc-a33b-021cd2adaabc.1700330997.1.1700331935..9bf25720-1794-4ca7-b19e-f53e627e9228..066bb4f0-c1a1-483a-af7a-56571e4e3c2d.1700330996963.14',
    'tmr_detect': '0%7C1700331937666',
    'sid': 'N2VlN2NkOTczYjljNGFjNGM1MjEzZGEzYWEyZDVhODg=|1700330159|a89de9658065c70b872d94de4b87d6b7ce524919',
    '_ga_120XMWN72V': 'GS1.1.1700330996.1.1.1700331965.0.0.0',
}

headers = {
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    # 'Cookie': 'is_seo_or_robot=seo; srv_menu_gender=women; lid=ZEACoWVY/fETVxk3poJPAgA=; _gcl_au=1.1.2004159184.1700330994; uxs_uid=acd8f210-863d-11ee-ac5a-295603813e4e; lmda_adBlocker=0; lmda_site_version=23.11.16; wt3_sid=%3B717012440280310; sessionId=17003309958823931367; is_synced=true; _gid=GA1.2.1095965336.1700330997; tmr_lvid=46e9ae520e08993a09fbd7096e3fefba; tmr_lvidTS=1700330996939; _sp_ses.d14a=*; _ym_uid=1700330997312631445; _ym_d=1700330997; _ym_isad=1; _ym_visorc=b; wt_geid=68934a3e9455fa72420237eb; search_gender=; qrator_ssid=1700330996.915.z7tIogZNFVoG0Rzj-uudfhjvdpq77k1v1thvdtmvmhd64iku9; gd_city=%D0%B3.%20%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0; gd_aoid=7700000000000; LMDA=gd_lat=55.755814:gd_long=37.617635; wt_cdbeid=1; wt3_eid=%3B717012440280310%7C2170033099598295355%232170033193455695664; wt_rla=717012440280310%2C13%2C1700330995867; _ga=GA1.2.543282526.1700330997; _dc_gtm_UA-20431685-1=1; _sp_id.d14a=c625dc77-ec72-45fc-a33b-021cd2adaabc.1700330997.1.1700331935..9bf25720-1794-4ca7-b19e-f53e627e9228..066bb4f0-c1a1-483a-af7a-56571e4e3c2d.1700330996963.14; tmr_detect=0%7C1700331937666; sid=N2VlN2NkOTczYjljNGFjNGM1MjEzZGEzYWEyZDVhODg=|1700330159|a89de9658065c70b872d94de4b87d6b7ce524919; _ga_120XMWN72V=GS1.1.1700330996.1.1.1700331965.0.0.0',
    'DNT': '1',
    'Referer': 'https://www.lamoda.ru/c/15/shoes-women/?sitelink=topmenuW&l=4&page=3',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'sitelink': 'topmenuW',
    'l': '4',
    'page': '3',
    'json': '1',
}

response = requests.get('https://www.lamoda.ru/c/15/shoes-women/', params=params, cookies=cookies, headers=headers)

# %%
if response.ok:
    analyzed_data = response.json()
    df = pd.DataFrame(columns=['name', 'price', 'sku', 'jpg'])
    products = analyzed_data['payload']['products']
    df['name'] = [p['name'] for p in products]
    df['price'] = [p['price_amount'] for p in products]
    df['sku'] = [p['sku'] for p in products]
    df['jpg'] = [p['thumbnail'] for p in products]

# %%
df
# Out:
#           name  price           sku                                     jpg
# 0       Дутики   3759  RTLACU933901     /R/T/RTLACU933901_20572766_1_v1.jpg
# 1      Ботинки   7199  MP002XW0TJSF     /M/P/MP002XW0TJSF_19189241_1_v2.jpg
# 2    Ботильоны   7990  MP002XW0XK7E     /M/P/MP002XW0XK7E_21631487_1_v1.jpg
# 3      Ботинки  11295  RTLACW826301     /R/T/RTLACW826301_20761058_1_v1.jpg
# 4    Кроссовки   5589  MP002XW0OBVO     /M/P/MP002XW0OBVO_20774981_1_v1.jpg
# 5         Сабо   2699  MP002XW0IUVP     /M/P/MP002XW0IUVP_19835631_1_v1.jpg
# 6       Сапоги  12599  MP002XW16R97     /M/P/MP002XW16R97_21354551_1_v1.jpg
# 7       Дутики   5499  MP002XW09LYU     /M/P/MP002XW09LYU_15379083_1_v1.jpg
# 8      Ботинки   6999  RTLADC638401     /R/T/RTLADC638401_21617042_1_v1.jpg
# 9        Туфли   3996  MP002XW0LPXY     /M/P/MP002XW0LPXY_18495456_1_v1.jpg
# 10     Ботинки   5699  RTLADC788901     /R/T/RTLADC788901_21633461_1_v1.jpg
# ...

# %%
for i in range(1, 10):
    params['page'] = i
